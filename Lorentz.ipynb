# %%
# eta: Lorentz metric
# T: infinitesimal Lorentz generator
tensor eta, T { a(4), b(4): SO(3, 1) };
tensor V { a(4): SO(3, 1) };

# Metric with one co- and one contravariant index is equivalent to Kronecker delta
var delta = g^a.b;

# Infinitesimal Lorentz transformation
var L = delta^a.b + T^a.b;

var V' = L^a.b V^b;

# Metric should be invariant under a Lorentz transformation

var zero1 = L.a^m L.b^n eta.m.n - eta.a.b;
var zero2 = distribute!(simp!(zero1));
var zero3 = distribute!(simp!(zero2));
var zero4 = distribute!(simp!(zero3));
var zero5 = elmetrics!(simp!(zero4));
# Out:
# <b># eta: Lorentz metric</b><br/>
# <b># T: infinitesimal Lorentz generator</b><br/>
# <span style="white-space: pre; font-family: monospace;">tensor eta, T {
#   a (4), b (4): SO (3, 1)
# } ;
# </span>
# <span style="white-space: pre; font-family: monospace;">tensor V {
#   a (4): SO (3, 1)
# } ;
# </span>
# <b># Metric with one co- and one contravariant index is equivalent to Kronecker delta</b><br/>
# <span style="white-space: pre; font-family: monospace;">[delta]: </span><math><mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></math><br>
# <b># Infinitesimal Lorentz transformation</b><br/>
# <span style="white-space: pre; font-family: monospace;">[L]: </span><math><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>a̲</mi></mi><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# </math><br>
# <span style="white-space: pre; font-family: monospace;">[V']: </span><math><mrow>
# <mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><mi><mi>z</mi></mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>a̲</mi></mi><mi><mi>z</mi></mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# <mo></mo><mmultiscripts>
# <mi>V</mi><none/><mi><mi>z</mi></mi>
# </mmultiscripts></mrow>
# </math><br>
# <b># Metric should be invariant under a Lorentz transformation</b><br/>
# <span style="white-space: pre; font-family: monospace;">[zero1]: </span><math><mrow>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>x</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>v</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>u</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>u</mi></mi><mi><mi>v</mi></mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>u</mi></mi><mi><mi>v</mi></mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>a̲</mi></mi><none/><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </math><br>
# <span style="white-space: pre; font-family: monospace;">[zero2]: </span><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>a̲</mi></mi><none/><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>x</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>T</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>)</mo>
# </mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>v</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>u</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>T</mi><none/><mi><mi>u</mi></mi><mi><mi>v</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>u</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><none/><mi><mi>u</mi></mi><mi><mi>v</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br>
# <span style="white-space: pre; font-family: monospace;">[zero3]: </span><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>a̲</mi></mi><none/><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mrow>
# <mo>(</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>x</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>x</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>v</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>v</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo>)</mo>
# </mrow>
# <mo></mo><mrow>
# <mo>(</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>u</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>t</mi></mi><mi><mi>u</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>t</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>u</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>s</mi></mi><mi><mi>u</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>s</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br>
# <span style="white-space: pre; font-family: monospace;">[zero4]: </span><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>a̲</mi></mi><none/><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>x</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>v</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>u</mi></mi><mi><mi>v</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>u</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>t</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>s</mi></mi><mi><mi>t</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><mi><mi>s</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>r</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>q</mi></mi><mi><mi>r</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>q

# %%
var zero6 = elmetrics!(simp!(zero5));
# Out:
# <span style="white-space: pre; font-family: monospace;">[zero6]: </span><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>a̲</mi></mi><none/><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><none/><mi><mi>b̲</mi></mi>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><none/><mi><mi>a̲</mi></mi>
# </mmultiscripts></mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>x</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>x</mi></mi><none/><none/><mi><mi>a̲</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>v</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>u</mi></mi><mi><mi>v</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>w</mi></mi><none/><mi><mi>u</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>t</mi></mi><none/><mi><mi>s</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>s</mi></mi><none/><none/><mi><mi>b̲</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>r</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>q</mi></mi><mi><mi>r</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>t</mi></mi><none/><mi><mi>q</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>p</mi></mi><none/><mi><mi>o</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>n</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>m</mi></mi><mi><mi>n</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>o</mi></mi><none/><mi><mi>m</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>l</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>k</mi></mi><mi><mi>l</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>p</mi></mi><none/><mi><mi>k</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br>

# %%
var zero7 = elmetrics!(simp!(zero6));
# Out:
# <span style="white-space: pre; font-family: monospace;">[zero7]: </span><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi>eta</mi><mi><mi>a̲</mi></mi><none/><mi><mi>b̲</mi></mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>z</mi></mi><none/><mi><mi>y</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>z</mi></mi><none/><none/><mi><mi>a̲</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>x</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>w</mi></mi><mi><mi>x</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>y</mi></mi><none/><mi><mi>w</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>v</mi></mi><none/><mi><mi>u</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>u</mi></mi><none/><none/><mi><mi>b̲</mi></mi>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>v</mi></mi><none/><none/><mi><mi>a̲</mi></mi>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>t</mi></mi><none/><mi><mi>s</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><mi><mi>s</mi></mi><none/><none/><mi><mi>b̲</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>r</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>q</mi></mi><mi><mi>r</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>t</mi></mi><none/><mi><mi>q</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi>eta</mi><mi><mi>p</mi></mi><none/><mi><mi>o</mi></mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>b̲</mi></mi><none/><mi><mi>n</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>m</mi></mi><mi><mi>n</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>o</mi></mi><none/><mi><mi>m</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi>g</mi><none/><mi><mi>a̲</mi></mi><none/><mi><mi>l</mi></mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi>T</mi><none/><mi><mi>k</mi></mi><mi><mi>l</mi></mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi>g</mi><mi><mi>p</mi></mi><none/><mi><mi>k</mi></mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br>

# %%
$\eta$.a.b
# Out:
# syntax error at line 1 due to lexer error
