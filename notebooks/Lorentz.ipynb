# %%
# eta: Lorentz metric
# T: infinitesimal Lorentz generator
tensor T { a(4), b(4): SO(3, 1) };
tensor V { a(4): SO(3, 1) };

anti_symmetric T;

# Metric with one co- and one contravariant index is equivalent to Kronecker delta
var delta = g^a.b;

# Infinitesimal Lorentz transformation
var L = delta^a.b + T^a.b;

var V' = L^a.b V^b;

# Metric should be invariant under a Lorentz transformation

var zero1 = L.a^m L.b^n g.m.n - g.a.b;
var zero2 = distribute!(simp!(zero1));
var zero3 = distribute!(simp!(zero2));
# Out:
# <strong># eta: Lorentz metric</strong><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <strong># T: infinitesimal Lorentz generator</strong><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">tensor T {
#   a (4), b (4): SO (3, 1)
# } ;
# </span><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">tensor V {
#   a (4): SO (3, 1)
# } ;
# </span><script>window.registerTensorHover();window.registerIndexHover();</script>
# anti_symmetric T
# <strong># Metric with one co- and one contravariant index is equivalent to Kronecker delta</strong><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">[delta]: </span><script>window.registerTensorHover();window.registerIndexHover();</script><math><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index a̲">a̲</mi><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts></math><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <strong># Infinitesimal Lorentz transformation</strong><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">[L]: </span><script>window.registerTensorHover();window.registerIndexHover();</script><math><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index a̲">a̲</mi><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi class="index a̲">a̲</mi><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts></mrow>
# </math><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">[V']: </span><script>window.registerTensorHover();window.registerIndexHover();</script><math><mrow>
# <mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index a̲">a̲</mi><mi class="index z">z</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi class="index a̲">a̲</mi><mi class="index z">z</mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# <mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor V">V</mi><none/><mi class="index z">z</mi>
# </mmultiscripts></mrow>
# </math><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <strong># Metric should be invariant under a Lorentz transformation</strong><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">[zero1]: </span><script>window.registerTensorHover();window.registerIndexHover();</script><math><mrow>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index z">z</mi><none/><mi class="index x">x</mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index a̲">a̲</mi><none/><mi class="index w">w</mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index w">w</mi><mi class="index x">x</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi class="index w">w</mi><mi class="index x">x</mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index y">y</mi><none/><mi class="index v">v</mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index b̲">b̲</mi><none/><mi class="index u">u</mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi class="index u">u</mi><mi class="index v">v</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi class="index u">u</mi><mi class="index v">v</mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index z">z</mi><none/><mi class="index y">y</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index a̲">a̲</mi><none/><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </math><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">[zero2]: </span><script>window.registerTensorHover();window.registerIndexHover();</script><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index a̲">a̲</mi><none/><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index b̲">b̲</mi><none/><mi class="index z">z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index a̲">a̲</mi><none/><none/><mi class="index z">z</mi>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index b̲">b̲</mi><none/><mi class="index z">z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index a̲">a̲</mi><none/><none/><mi class="index z">z</mi>
# </mmultiscripts></mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index b̲">b̲</mi><none/><mi class="index z">z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index a̲">a̲</mi><none/><none/><mi class="index z">z</mi>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index b̲">b̲</mi><none/><mi class="index z">z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index a̲">a̲</mi><none/><none/><mi class="index z">z</mi>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br><script>window.registerTensorHover();window.registerIndexHover();</script>
# <span style="white-space: pre; font-family: monospace;">[zero3]: </span><script>window.registerTensorHover();window.registerIndexHover();</script><math><mrow>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index b̲">b̲</mi><none/><mi class="index a̲">a̲</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index a̲">a̲</mi><none/><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index a̲">a̲</mi><none/><mi class="index b̲">b̲</mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# <mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi class="index b̲">b̲</mi><none/><mi class="index a̲">a̲</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index a̲">a̲</mi><none/><none/><mi class="index z">z</mi>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi class="index b̲">b̲</mi><none/><mi class="index z">z</mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </math><br><script>window.registerTensorHover();window.registerIndexHover();</script>

# %%
collect!(simp!(simp!(canon!(zero3))));
