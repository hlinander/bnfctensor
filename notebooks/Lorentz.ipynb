# %%
# eta: Lorentz metric
# T: infinitesimal Lorentz generator
tensor eta, T { a(4), b(4): SO(3, 1) };
tensor V { a(4): SO(3, 1) };

# Metric with one co- and one contravariant index is equivalent to Kronecker delta
var delta = g^a.b;

# Infinitesimal Lorentz transformation
var L = delta^a.b + T^a.b;

var V' = L^a.b V^b;

# Metric should be invariant under a Lorentz transformation

var zero1 = L.a^m L.b^n g.m.n - g.a.b;
var zero2 = distribute!(simp!(zero1));
var zero3 = distribute!(simp!(zero2));
# Out:
# <strong># eta: Lorentz metric</strong><br><script>registerTensorHover();</script>
# <strong># T: infinitesimal Lorentz generator</strong><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">tensor eta, T {
#   a (4), b (4) : SO (3, 1)
# } ;
# </span><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">tensor V {
#   a (4) : SO (3, 1)
# } ;
# </span><script>registerTensorHover();</script>
# <strong># Metric with one co- and one contravariant index is equivalent to Kronecker delta</strong><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">[delta]: </span><script>registerTensorHover();</script><math><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>a̲</mi><mi>b̲</mi><none/>
# </mmultiscripts></math><br><script>registerTensorHover();</script>
# <strong># Infinitesimal Lorentz transformation</strong><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">[L]: </span><script>registerTensorHover();</script><math><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>a̲</mi><mi>b̲</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi>a̲</mi><mi>b̲</mi><none/>
# </mmultiscripts></mrow>
# </math><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">[V']: </span><script>registerTensorHover();</script><math><mrow>
# <mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>a̲</mi><mi>z</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi>a̲</mi><mi>z</mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# <mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor V">V</mi><none/><mi>z</mi>
# </mmultiscripts></mrow>
# </math><br><script>registerTensorHover();</script>
# <strong># Metric should be invariant under a Lorentz transformation</strong><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">[zero1]: </span><script>registerTensorHover();</script><math><mrow>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>z</mi><none/><mi>x</mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>a̲</mi><none/><mi>w</mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>w</mi><mi>x</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi>w</mi><mi>x</mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# <mo></mo><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>y</mi><none/><mi>v</mi>
# </mmultiscripts><mo></mo><mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>b̲</mi><none/><mi>u</mi><none/>
# </mmultiscripts><mo></mo><mrow>
# <mo>(</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><none/><mi>u</mi><mi>v</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><none/><mi>u</mi><mi>v</mi><none/>
# </mmultiscripts><mo>)</mo>
# </mrow>
# </mrow>
# </mrow>
# </mrow>
# <mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>z</mi><none/><mi>y</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>a̲</mi><none/><mi>b̲</mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </math><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">[zero2]: </span><script>registerTensorHover();</script><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>a̲</mi><none/><mi>b̲</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>b̲</mi><none/><mi>z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>a̲</mi><none/><none/><mi>z</mi>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>b̲</mi><none/><mi>z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>a̲</mi><none/><none/><mi>z</mi>
# </mmultiscripts></mrow>
# </mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>b̲</mi><none/><mi>z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>a̲</mi><none/><none/><mi>z</mi>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>b̲</mi><none/><mi>z</mi><none/>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>a̲</mi><none/><none/><mi>z</mi>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br><script>registerTensorHover();</script>
# <span style="white-space: pre; font-family: monospace;">[zero3]: </span><script>registerTensorHover();</script><math><mrow>
# <mrow>
# <mn>-1</mn><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>a̲</mi><none/><mi>b̲</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>a̲</mi><none/><mi>b̲</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor g">g</mi><mi>b̲</mi><none/><mi>a̲</mi><none/>
# </mmultiscripts></mrow>
# <mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>b̲</mi><none/><mi>a̲</mi><none/>
# </mmultiscripts><mo>+</mo>
# <mrow>
# <mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>a̲</mi><none/><none/><mi>z</mi>
# </mmultiscripts><mo></mo><mmultiscripts>
# <mi mathvariant="bold" class="tensor T">T</mi><mi>b̲</mi><none/><mi>z</mi><none/>
# </mmultiscripts></mrow>
# </mrow>
# </mrow>
# </mrow>
# </math><br><script>registerTensorHover();</script>

# %%
canon!(zero3);
